# %%
import requests

url = "https://api.themoviedb.org/3/tv/top_rated"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4YjMwMTEzZDQ4ODE5MTBjNmYwMzIwM2E1ZGZhOTRjMCIsInN1YiI6IjY0YjRmY2VmMTIxOTdlMDBmZjAxZjgxZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DVTVDonGP2C_UID5j_reH-Hk0DRfvvYJf1vEeW30jNw"
}

response = requests.get(url, headers=headers).json()

print(response)
# Out:
# {'page': 1, 'results': [{'backdrop_path': '/84XPpjGvxNyExjSuLQe0SzioErt.jpg', 'first_air_date': '2008-01-20', 'genre_ids': [18, 80], 'id': 1396, 'name': 'Breaking Bad', 'origin_country': ['US'], 'original_language': 'en', 'original_name': 'Breaking Bad', 'overview': "When Walter White, a New Mexico chemistry teacher, is diagnosed with Stage III cancer and given a prognosis of only two years left to live. He becomes filled with a sense of fearlessness and an unrelenting desire to secure his family's financial future at any cost as he enters the dangerous world of drugs and crime.", 'popularity': 234.125, 'poster_path': '/ggFHVNu6YYI5L9pCfOacjizRGt.jpg', 'vote_average': 8.9, 'vote_count': 11975}, {'backdrop_path': '/rkB4LyZHo1NHXFEDHl9vSD9r1lI.jpg', 'first_air_date': '2021-11-06', 'genre_ids': [16, 18, 10765, 10759], 'id': 94605, 'name': 'Arcane', 'origin_country': ['US'], 'original_language': 'en', 'original_name': 'Arcane', 'overview': 'Amid the stark discord of twin cities Piltover 
# ...

# %%
for i in response['results']:
  print(i['name'],i['vote_average'])
# Out:
# Breaking Bad 8.9
# Arcane 8.8
# One Piece 8.7
# Be Eternal: Champions of America 8.7
# Rick and Morty 8.7
# Fullmetal Alchemist: Brotherhood 8.7
# Anne with an E 8.7
# Goblin 8.7
# The Last of Us 8.7
# The Owl House 8.7
# Invincible 8.7
# Avatar: The Last Airbender 8.7
# Demon Slayer: Kimetsu no Yaiba 8.7
# My Hero Academia 8.7
# Regular Show 8.7
# Once 8.7
# Romantic Killer 8.7
# Young Royals 8.7
# Hunter x Hunter 8.7
# Attack on Titan 8.7

# %%
import pandas as pd
popularity = []
vote_count = []
original_language = []
name = []
vote_average = []
overview = []
release_date = []

for i in response['results']:
    popularity.append(i['popularity'])
    vote_count.append(i['vote_count'])
    original_language.append(i['original_language'])
    name.append(i['name'])
    vote_average.append(i['vote_average'])
d={'name':name,'original_language':original_language,'popularity':popularity,'vote_count':vote_count,'vote_average':vote_average}

df = pd.DataFrame(d)
df
# Out:
#                                 name original_language  popularity  \
# 0                       Breaking Bad                en     234.125
# 1                             Arcane                en      57.885
# 2                          One Piece                ja     119.991
# 3   Be Eternal: Champions of America                es      15.213
# 4                     Rick and Morty                en     263.744
# 5   Fullmetal Alchemist: Brotherhood                ja      62.810
# 6                     Anne with an E                en      76.940
# 7                             Goblin                ko      67.358
# 8                     The Last of Us                en     224.287
# 9                      The Owl House                en     214.161
# 10                        Invincible                en      76.900
# 11        Avatar: The Last Airbender                en      60.417
# 12    Demon Slayer: Kimetsu no Yaiba                ja     111.707
# ...

# %%
df.shape
# Out:
# (20, 5)

# %%
df.to_csv('topratedtvshows2023.csv')
